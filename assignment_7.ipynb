# %%
# Question 1

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

df = pd.read_csv("D:/Acadview training notes/titanic.csv")
df.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                             Mr. Owen Harris Braund
# 1         1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2         1       3                              Miss. Laina Heikkinen
# 3         1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4         0       3                            Mr. William Henry Allen
#
#       Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# 0    male  22.0                        1                        0   7.2500
# 1  female  38.0                        1                        0  71.2833
# 2  female  26.0                        0                        0   7.9250
# 3  female  35.0                        1                        0  53.1000
# 4    male  35.0                        0                        0   8.0500

# %% [markdown]
# This data set is about the titanic ship. This data is of shape 887,8. It contains 8 columns, 4 categorical columns and 4 Numerical columns

# %%
# Question 2
df.isnull().sum()
# Out:
# Survived                   0
# Pclass                     0
# Name                       0
# Sex                        0
# Age                        0
# Siblings/Spouses Aboard    0
# Parents/Children Aboard    0
# Fare                       0
# dtype: int64

# %% [markdown]
# This data contains no null values.

# %%
# Question 3
plt.hist(df['Fare'])
plt.xlabel('Fare')
plt.ylabel('count')
plt.show()

# %% [markdown]
# This graph shows the how many people paid a particular cost for the voyage

# %%
sns.distplot(df['Age'])
plt.ylabel('Distribution')
# Out:
# Text(0,0.5,'Distribution')

# %% [markdown]
# This graph shows the distribution of the age of the people on the ships. It shows the avg age of the people on ship lied between 20 to 30

# %%
sns.kdeplot(df.Age,shade=True)

# %% [markdown]
# This graph shows the shaded region of the age distribution of the passengers

# %%
sns.boxplot(x=df.Age,data = df)

# %% [markdown]
# This Box plot shows the 75 % passengers were of 27 to 40 age

# %%
sns.countplot(x=df.Sex, data = df)

# %% [markdown]
# This count plot shows the number of male and female on the board

# %%
# Question 4
sns.kdeplot(df.Age,df.Survived)

# %% [markdown]
# This kde plot shows the age distribution of age who survived and died

# %%
plt.scatter(df.Fare,df.Pclass)
plt.xlabel('Fare')
plt.ylabel('Pclass')
plt.show()

# %% [markdown]
# This plot shows the scatter of the fare at each pclass

# %%
plt.figure(figsize=(10,8))
sns.stripplot(x='Sex',y='Age',data=df)

# %%
This strip plot shows the age of every person either male or female

# %%
plt.scatter(df.Age,df.Fare)

# %% [markdown]
# This scatter plot shows the ticket purchased by passenger of each age. This shows a heavy density of people paid less to travel which was around 100$

# %%
sns.swarmplot(x='Age',y='Fare',data=df)

# %% [markdown]
# This plot gives the scatter plot of age and fare with better visualization

# %%
sns.barplot(x='Sex',y='Survived',data=df)

# %%
It is an intresting plot which shows the male survival was around 0.1 to 0.2 where as the probablity of female survival was 0.7 to 0.8

# %%
sns.barplot(x='Survived',y='Age',data=df)

# %% [markdown]
# This plot shows the age of people that survived and died

# %%
sns.barplot(x='Pclass',y='Fare',data=df)

# %% [markdown]
# This bar plot shows the fare of each class

# %%
sns.boxplot(x='Pclass',y='Fare',data=df)

# %% [markdown]
# This box plot indicates the fare of each class giving outliers

# %%
plt.figure(figsize=(10,8))
corr =df.corr()
sns.heatmap(corr)
df.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                             Mr. Owen Harris Braund
# 1         1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2         1       3                              Miss. Laina Heikkinen
# 3         1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4         0       3                            Mr. William Henry Allen
#
#       Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# 0    male  22.0                        1                        0   7.2500
# 1  female  38.0                        1                        0  71.2833
# 2  female  26.0                        0                        0   7.9250
# 3  female  35.0                        1                        0  53.1000
# 4    male  35.0                        0                        0   8.0500

# %% [markdown]
# This heat map shows the correlation of all the columns with each other
# here there is not much correlation but having siblings spouses and having parents childrens are somewhat related

# %%
sns.pairplot(df)

# %% [markdown]
# pair plot shows the visualization of all the graph with each other it is very essential to find the relation between them
